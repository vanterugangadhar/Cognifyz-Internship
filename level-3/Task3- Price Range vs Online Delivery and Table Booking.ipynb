# %% [markdown]
# ## Level 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\vante\OneDrive\Desktop\Dataset  cognify og.csv")
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# ## Task 3: Price Range vs Online Delivery and Table Booking

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [markdown]
# ## Task:- Analyze if there is a relationship between the price range and the availability of online delivery and table booking.

# %%
x1=df['Has Online delivery']
x2=df['Has Table booking']
y=df['Average Cost for two']

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,2)
sns.boxplot(x=x1,y=y)
plt.title('Online delivery affected by cost')
plt.subplot(1,2,1)
sns.boxplot(x=x2, y=y)
plt.title('Table Booking affected by cost')
plt.tight_layout()
plt.show()

# %%
print('Both the Online delivery and Table booking has Negative impact by Cost')
print('The High-paid Restaurants which has avg cost more than 10000 doesn"t provide these facilities')
# Out:
# Both the Online delivery and Table booking has Negative impact by Cost
# The High-paid Restaurants which has avg cost more than 10000 doesn"t provide these facilities

# %% [markdown]
# ## Task:- Determine if higher-priced restaurants are more likely to offer these services.

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,2)
sns.boxplot(x=x1,y='Average Cost for two',data=df.loc[df['Average Cost for two']<10000])
plt.title('Online delivery affected by cost')
plt.subplot(1,2,1)
sns.boxplot(x=x2, y='Average Cost for two',data=df.loc[df['Average Cost for two']<10000])
plt.title('Table Booking affected by cost')
plt.tight_layout()
plt.show()

# %%
print('The Online delivery is provided by restaurants which has average cost less than 1000')
print('The Table booking is provided by restaurants which has average cost range of 1000 and 2000')
# Out:
# The Online delivery is provided by restaurants which has average cost less than 1000
# The Table booking is provided by restaurants which has average cost range of 1000 and 2000
